# %%
import sys
sys.path.append('/content/drive/My Drive/GCN')

# %%
# !python /content/drive/My\ Drive/GCN/setup.py install
# Out:
# running install
# running bdist_egg
# running egg_info
# creating gcn.egg-info
# writing gcn.egg-info/PKG-INFO
# writing dependency_links to gcn.egg-info/dependency_links.txt
# writing requirements to gcn.egg-info/requires.txt
# writing top-level names to gcn.egg-info/top_level.txt
# writing manifest file 'gcn.egg-info/SOURCES.txt'
# reading manifest file 'gcn.egg-info/SOURCES.txt'
# writing manifest file 'gcn.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# ...
#
# creating build
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying gcn.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying gcn.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying gcn.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying gcn.egg-info/requires.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# ...

# %%
import sys
sys.path.append('/content/drive/My Drive/GCN/gcn')

# %%
# !cd /content/drive/My\ Drive/GCN/gcn

# %%
# %tensorflow_version 1.x
import tensorflow as tf
# Out:
# TensorFlow 1.x selected.

# %%
# !python /content/drive/My\ Drive/GCN/gcn/train.py
# Out:
# WARNING:tensorflow:From /content/drive/My Drive/GCN/gcn/train.py:13: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/GCN/gcn/train.py:50: The name tf.sparse_placeholder is deprecated. Please use tf.compat.v1.sparse_placeholder instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/GCN/gcn/train.py:52: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/GCN/gcn/train.py:54: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /content/drive/My Drive/GCN/gcn/models.py:142: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# ...
